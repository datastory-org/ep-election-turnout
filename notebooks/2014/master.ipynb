# %%
import pandas as pd
import geopandas as gpd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import numpy as np
import requests
import glob

# %config InlineBackend.figure_format = 'retina'
pd.options.mode.chained_assignment = None

# %%
shapefiles = []
for shapefile in glob.glob('../../data/processed/*/*.shp'):
    shapefiles.append(gpd.read_file(shapefile))

# %%
#plt.ioff()
#for shapefile in shapefiles:
#    ax = shapefile.plot(figsize=(12, 6), column='turnout', scheme='Fisher_Jenks', legend=True)
#    ax.set_axis_off()
#    ax.set_title(shapefile.country.iloc[0])
#    ax.get_figure().savefig(f'../../reports/{shapefile.country.iloc[0]}.png')

# %%
geo = pd.concat(shapefiles, sort=True)

# %%
(geo.turnout < 40).value_counts()
# Out:
# False    68022
# True     27464
# Name: turnout, dtype: int64

# %%
ax = geo.plot(figsize=(16, 16), column='turnout')
ax.set_xlim(-11.5, 35)
ax.set_ylim(34, 71)
ax.set_axis_off();
